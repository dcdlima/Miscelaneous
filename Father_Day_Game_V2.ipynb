# %%
import tkinter as tk
import random

# Lista de frases
questions = [
    "Can you describe your father in one word? Why that word?.",
    "What’s your favorite memory with your dad?",
    "What lesson did your father teach you that you’ll never forget?",
    "What’s something your dad always says?",
    "Do you and your father have any traditions?",
    "What’s one thing you admire most about your father?",
    "What’s something you’ve done that made your dad proud?",
    "If you could say anything to your dad right now, what would it be?",
    "How do you celebrate Father’s Day in your family?",
    "Is there a movie or song that reminds you of your dad?",
    "What’s the most “dad” thing your father does?",
    "What kind of father do you want to be (or marry, or have)?",
    "What values did your father teach you?",
    "What's one thing you would like to do with your father but haven't done yet?",
    "What kind of music, food, or movies does your father enjoy?",
    "What gift would you give your father if money wasn't a problem?",
    "Do you think you are similar to your father? In what ways?",
    "Who do you admire more: your father or another male figure in your life? Why?",
    "What's one thing you would do differently if you were a father?"
    "If you could take your father on a dream trip, where would you go?"


]

# Cópia da lista para controle interno
#remaining_questions = questions.copy()

# Função para sortear
def draw_question():
   # global remaining_questions
   # if remaining_questions:
    question = random.choice(questions)
        #remaining_questions.remove(question)
    question_label.config(text=question)
    #else:
       # question_label.config(text="All questions have been drawn. 🎉")

# Criando a janela
root = tk.Tk()
root.title("Father’s Day - Question Picker")
root.geometry("600x300")

# Label para exibir a pergunta
question_label = tk.Label(root, text="Click the button to draw a question!", wraplength=550, font=("Arial", 36), justify="center")
question_label.pack(pady=40)

# Botão para sortear pergunta
draw_button = tk.Button(root, text="Draw Question 🎲", command=draw_question, font=("Arial", 36), bg="#4CAF50", fg="white")
draw_button.pack()

# Iniciar o app
root.mainloop()


# Sorteia uma frase aleatória
#frase_sorteada = random.choice(frases)

# Exibe a frase sorteada
#print("Frase sorteada:")
#print(frase_sorteada)
